# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Data Acquire

# %%
train_df = pd.read_csv('Dataset/train.csv')
test_df = pd.read_csv('Dataset/test.csv')
combine = [train_df, test_df]

# %% [markdown]
# # Data Description

# %%
# Name of Columns
print(train_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
# First 5 values in the CSV file
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Last 5 values in the CSV file
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Information of Train and Test Dataset
train_df.info()
print('*'*50)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# **************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
# Retriving few statistical values of train dataset
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Analyzing the pivoting feature Pclass in te dataset
train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
# Analyzing the pivoting feature Sex in te dataset
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# Analyzing the pivoting feature SibSp in te dataset
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
# Analyzing the pivoting feature Parch in te dataset
train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# # Data Vizualization

# %%
# Vizualization of Survival rate with age range
map1=sns.FacetGrid(train_df, col='Survived')
map1.map(plt.hist, 'Age', bins=20)

# %%
# Vizualization of Survival rate and Pclass type with age range
map2=sns.FacetGrid(train_df, col='Survived', row='Pclass', size=2.2, aspect=1.6)
map2.map(plt.hist, 'Age', alpha=.5, bins=20)
map2.add_legend()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Vizualization of Survival rate and Embarked type with Pclass type
map3=sns.FacetGrid(train_df, row='Embarked', size=2.2, aspect=1.6)
map3.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
map3.add_legend()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:675: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Vizualization of Survival rate and Embarked type with sex type
map4=sns.FacetGrid(train_df, row='Embarked', col='Survived', size=2.2, aspect=1.6)
map4.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
map4.add_legend()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Wrangling of Data

# %%
# Deleting the less correlated columns with the Survival Column(Response) 
print("Before", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)
train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
test_df = test_df.drop(['Ticket', 'Cabin'], axis=1)
combine = [train_df, test_df]
"After", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape
# Out:
# Before (891, 12) (418, 11) (891, 12) (418, 11)
# ('After', (891, 10), (418, 9), (891, 10), (418, 9))

# %%
# We can create a new column to better differentiate the passengers by assigning the titles to them by their names.
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %%
# Now we can drop Name and use Title instead. There will be no use of PassengerID in survival rate as well.
train_df = train_df.drop(['Name', 'PassengerId'], axis=1)
test_df = test_df.drop(['Name'], axis=1)
combine = [train_df, test_df]
train_df.shape, test_df.shape
# Out:
# ((891, 9), (418, 9))

# %%
# Converting string values to integer values in Sex column i.e. female=1 and male=0
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
# Creation of categorical numerical Feature for removing missing or null values in the Age column
grid_map=sns.FacetGrid(train_df, row='Pclass', col='Sex', size=2.2, aspect=1.6)
grid_map.map(plt.hist, 'Age', alpha=.5, bins=20)
grid_map.add_legend()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
guess_ages = np.zeros((2,3))
guess_ages
# For this classification,we will iterate over Sex (0 or 1) and Pclass (1, 2, 3) to calculate guessed values of Age and categorize them in six combinations.
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & (dataset['Pclass'] == j+1)]['Age'].dropna()
            age_guess = guess_df.median()
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5  
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]
    dataset['Age'] = dataset['Age'].astype(int)

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      1
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      1

# %%
# Creation of AgeBand column to check the correlation with Survival column(Response)
train_df['AgeBand'] = pd.cut(train_df['Age'], 5)
train_df[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
# Based on the AgeBand column, we will create ordinals in Age column with this column.
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age']
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1
#
#         AgeBand
# 0  (16.0, 32.0]
# 1  (32.0, 48.0]
# 2  (16.0, 32.0]
# 3  (32.0, 48.0]
# 4  (32.0, 48.0]

# %%
# Now the purpose AgeBand column is fulfilled. So, we will drop that column.
train_df = train_df.drop(['AgeBand'], axis=1)
combine = [train_df, test_df]
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1

# %%
# We can create a new column to better differentiate the passengers by assigning the FamilySize to them by their sibsp column.
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
train_df[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
# We can create another feature to identify people aborded the Titanic alone as IsAlone feature.
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
train_df[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
# Now we can drop Parch, SibSp and FamilySize columns as we have a consolidated column called IsAlone.
train_df = train_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
test_df = test_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
combine = [train_df, test_df]
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  Title  IsAlone
# 0         0       3    0    1   7.2500        S      1        0
# 1         1       1    1    2  71.2833        C      3        0
# 2         1       3    1    1   7.9250        S      2        1
# 3         1       1    1    2  53.1000        S      3        0
# 4         0       3    0    2   8.0500        S      1        1

# %%
# Creation of another feature which is combination of Age and Pclass called Age_mul_Pclass.
for dataset in combine:
    dataset['Age*Class'] = dataset.Age * dataset.Pclass
train_df.loc[:, ['Age*Class', 'Age', 'Pclass']].head(10)
# Out:
#    Age*Class  Age  Pclass
# 0          3    1       3
# 1          2    2       1
# 2          3    1       3
# 3          2    2       1
# 4          6    2       3
# 5          3    1       3
# 6          3    3       1
# 7          0    0       3
# 8          3    1       3
# 9          0    0       2

# %%
# Filling the two missing values in the Embarked feature by the most occuring value in that feature to address the missing values.
freq_port = train_df.Embarked.dropna().mode()[0]

for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
train_df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
# Converting of string values in Embarked column to a numerical value.
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1   7.2500         0      1        0          3
# 1         1       1    1    2  71.2833         1      3        0          2
# 2         1       3    1    1   7.9250         0      2        1          3
# 3         1       1    1    2  53.1000         0      3        0          2
# 4         0       3    0    2   8.0500         0      1        1          6

# %%
# Filling the single missing value of Fare column in test dataset by using median.
test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True)
test_df.head()
# Out:
#    PassengerId  Pclass  Sex  Age     Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    2   7.8292         2      1        1          6
# 1          893       3    1    2   7.0000         0      3        0          6
# 2          894       2    0    3   9.6875         2      1        1          6
# 3          895       3    0    1   8.6625         0      1        1          3
# 4          896       3    1    1  12.2875         0      3        0          3

# %%
# Creation of FareBand column to check the correlation with Survival column(Response)
train_df['FareBand'] = pd.qcut(train_df['Fare'], 4)
train_df[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
# Based on the FareBand column, we will create ordinals in Fare column with this column.
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
train_df = train_df.drop(['FareBand'], axis=1)
combine = [train_df, test_df]   
train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         0      1        0          3
# 1         1       1    1    2     3         1      3        0          2
# 2         1       3    1    1     1         0      2        1          3
# 3         1       1    1    2     3         0      3        0          2
# 4         0       3    0    2     1         0      1        1          6
# 5         0       3    0    1     1         2      1        1          3
# 6         0       1    0    3     3         0      1        1          3
# 7         0       3    0    0     2         0      4        0          0
# 8         1       3    1    1     1         0      3        0          3
# 9         1       2    1    0     2         1      3        0          0

# %% [markdown]
# ## Models for Prediction

# %%
# First we have to find the correlation of the features with Survived feature(Response).
coeff_df = pd.DataFrame(train_df.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#      Feature  Correlation
# 1        Sex     2.201619
# 5      Title     0.397888
# 2        Age     0.287011
# 4   Embarked     0.261473
# 6    IsAlone     0.126553
# 3       Fare    -0.086655
# 7  Age*Class    -0.311069
# 0     Pclass    -0.750700

# %%
X_train = train_df.drop("Survived", axis=1)
Y_train = train_df["Survived"]
X_test  = test_df.drop("PassengerId", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 80.36

# %% [markdown]
# ### Support Vector Machines

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 78.23

# %% [markdown]
# ### K-Nearest Neighbour

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 84.85

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian
# Out:
# 72.28

# %% [markdown]
# ### Perceptron

# %%
perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron
# Out:
# 78.34

# %% [markdown]
# ### Linear SVC

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 79.12

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd
# Out:
# 61.95

# %% [markdown]
# ### Decision Tree

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 86.76

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest
# Out:
# 86.76

# %% [markdown]
# ## Best-Fit Model Selection and Evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree'],
    'Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 3               Random Forest  86.76
# 8               Decision Tree  86.76
# 1                         KNN  84.85
# 2         Logistic Regression  80.36
# 7                  Linear SVC  79.12
# 5                  Perceptron  78.34
# 0     Support Vector Machines  78.23
# 4                 Naive Bayes  72.28
# 6  Stochastic Gradient Decent  61.95

# %% [markdown]
# We can see that Random Forest and Decision Tree are giving the best accuracy of 86.76%. We can use any of the model to predict the Survival of the passengers in the test set. Here, I will use Decision Tree.

# %%
Y_pred = decision_tree.predict(X_test)
submission = pd.DataFrame({
        "PassengerId": test_df["PassengerId"],
        "Survived": Y_pred
    })

# %%
submission.to_csv('submission.csv', index=False)
